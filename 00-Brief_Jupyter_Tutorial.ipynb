# %% [markdown]
# # An extremely brief Jupyter notebook tutorial
#
#
# If this is your first contact with Jupyter notebooks, this should give you a quick overview on how to use them. The tutorial will not make you a wizzard but it should suffice in enabeling you to run and play with the examples.
#
# Should you get hooked and want to explore the possibilities more of the  Jupyter notebook, please go to project site of [Project Jupyter](https://jupyter.org). Here you can find more info as well as an in-depth [tutorial](https://mybinder.org/v2/gh/ipython/ipython-in-depth/master?filepath=binder/Index.ipynb).
#
# All notebooks are split up into cells that can contain differnt types of content. The one you are currently reading contains text, whereas the one below contains code.
# When you click on the cell below, it should be highlighted in green and pressen `shift+enter` will run the cell and display the result:

# %%
1 + 1

# %% [markdown]
# You can also edit the code in the cell. Go ahead and try that. After editing the cell, you can rerun it by pressing `shift+enter` again.
#
# Now you are basically able to start going into the tutorials that you find on the Index page.
#
# You will see in the examples, that the notebook will also displays plots that where generated by the code in the cells.
#
# One more realy usefull thing is that you can call a functions followed by a `?` to display the help or followed by two `??` to display the code. Just in case you want to see behind some of the functions, or how you are supposed to use them
