# %% [markdown]
# # An extremely brief Jupyter notebook tutorial
#
#
# If this is your first contact with jupyter notebooks, this should give you a quick overview on how to use them. The tutorial will not make you a wizzard in the use of the notebook but it should suffice in enabeling you to run and play with the examples.
#
# Should you get hooked and want to explore the possibilities more, please go to project size of [Project Jupyter](https://jupyter.org). Where you can find more info as well as an in-depth [tutorial](https://mybinder.org/v2/gh/ipython/ipython-in-depth/master?filepath=binder/Index.ipynb).
#
# All notebooks are split up into cells that can contain differnt types of content. The one you are currently reading contains text, wheras the one below contains code.
# When you click on the cell below, it should be highlighted in green and pressen `shift+enter` will run the cell and display the result:

# %%
1 + 1

# %% [markdown]
# You can edit any cell by double clicking on it:

# %% [markdown]
# After editing the cell, you can rerun it by pressing `shift+enter` again.
#
# Now you are basically able to start going into the tutorials that you find on the Index page.
#
# You will see that the notebook will also displays plots that where generated by the code in the cells.
